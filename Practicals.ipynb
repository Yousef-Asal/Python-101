# %% [markdown]
# # Practicals' Solutions
# In this notebook will be the solution to all practicals for the book **Introdution to Programming with Python**.
#
# It will be organized and partitioned based on the book chapters with each practical in its own cell.

# %% [markdown]
# ## Ch1. Programs and Variables

# %% [markdown]
# ### 1.7.1 Print Function

# %%
print('Hello!! My name is Fawzy')
print('I am ' + str(29) + ' years old')
print('And I have an exam worth\n', 2.4, 'points')

# %% [markdown]
# ### 1.7.2 Comments

# %%
# You can write down a comment using the operator (#)
x = 7  # You can also write a comment in the same line as an operation

# %% [markdown]
# ### 1.7.3 Variables

# %%
# Q1
x0 = 10 + 3
x1 = (10+2) / 3
x2 = 10 * 4
x3 = 10 - 5
print(x0,x1,x2,x3)

# Q2
y0 = x0 * 2
y1 = x1 / 2
y2 = x2 + 6
y3 = x3 + 7
print(y0,y1,y2,y3)

#Q3,Q4
var0 = 10
var1 = 2
var3 = 3
var4 = 12

out0 = var0 ** var1
out1 = var0 // var3
out2 = var0 % var1
print(out0,out1,out2)

#Q5,Q6,Q7
str0 = 'Hello!! This is "Hamed"'
str1 = "Hello Hamed!! My name is 'Qabil'"
out_str = str0 + '\n' + str1
print(out_str)
print(str0 + '\t' +str1)

#Q8
print(var0==var1)
print(var0>var3)
print(var1<var3)
print(var3>= var1)
print(var4<=var0)
print(var1!=var0)

#Q9
str2 = 'dog'
str3 = 'Dog'

out3 = str2==str3
out4 = str2!=str3
print(out3)
print(out4)

#Q10
out5 = var0>=var1 and var1<= var3
out6 = var0>=var1 or var1== var3
out7 = var4<=var0
print(var0>=var1, var1<= var3, out5)
print(var0>=var1, var1== var3, out6)
print(var4==var0, out7)

# %% [markdown]
# ## Ch2. Control Statements

# %% [markdown]
# ### 2.4.2 If Statemnts

# %%
x = 15
y = 10
z = 5
a = 10.1

if a >= y:
    print('Floating points matter')
print('Hello from outside the if')

# %% [markdown]
# ### 2.4.3 More on Indentation

# %%
if a >= z:
    print('a is bigger than z')
    if a >= y:
        print('Ok a is also bigger than y')
        if a >= x:
            print('a is the goat. Bigger than them all')

# %% [markdown]
# ### 2.4.4 If, Elif, Else

# %%
#Q1
if x > y:
    print("I'm with you bro")
if x > z:
    print('Me too')
if x > a:
    print('Me three')

print('*' * 20)

if x > y:
    print("You don't need these other two")
elif x > z:
    print("You didn't even check me.")
elif x > a:
    print('Bruhhh')

#Q2
if z > a:
    print("You picked me. That's new")
elif z > y:
    print("No way this is happening")
else:
    print("Yeah, that's more like it")

# %% [markdown]
# ### 2.4.5 For Loop

# %%
#Q1, Q2
for i in range(10):
    print(f"This is iteration number {i}")

print('*' * 20)

for i in range(5,15):
    print(i)

print('*' * 20)

#Q3
for i in range(5):
    print('i = ', i)
    for j in range(i, i+5):
        print('j = ', j)

# %% [markdown]
# ### 2.4.6 While Loop

# %%
x = 0
while x < 10:
    print("This is iteration number: ", x)
    x += 1
print('While loop finished')

# %% [markdown]
# ## Ch3 More Variables

# %% [markdown]
# ### 3.3.1 Lists

# %%
#Q1
lst0 = list()
lst1 = []
print(lst0,lst1)

#Q2,Q3,Q4,Q5
lst0 = [12,2.2,'dog']
lst1 = [False, 'cat', [1,2,3]]
print(lst1[1])
print(lst0[-1])
lst0[0] = 10
print(lst0)

#Q6
lst2 = lst0 + lst1
print(lst2)

#Q7,Q8,Q9,Q10
lst0.insert(1, 'Ant')
print(lst0)
lst0.append(True)
print(lst0)
lst0.pop()
lst0.pop(3)
print(lst0)

# %% [markdown]
# ### 3.3.2 Dictionaries

# %%
#Q1 
dit0 = {}
dit1 = dict()
print(dit0,dit1)

#Q2,Q3,Q4,Q5
dit0 = {'one': 1, 2: 'two', 'true': True, 'lst': [12, 2.2, 'dog']}
print(dit0['one'])
dit0['new'] = 144
print(dit0)
dit0['new'] = 2025
print(dit0)

#Q6
dit0.pop()
dit0.pop('new')
print(dit0)

# %% [markdown]
# ## Ch4. Loops on Lists and Dicts

# %% [markdown]
# ### 4.3.1 Looping Over Lists

# %%
#Q1,Q2
lst0 = [10 ,20 ,30 ,40 ,50]
for i in range(len(lst0)):
    print('The value is: ', lst0[i])

#Q3,Q4
lst1 = [11, 'cow', 3.3, False]
for c in range(len(lst1)):
    print('The value for lst1 is: ', lst1[c])

print("*"*20)

# %% [markdown]
# ### 4.3.2 Directly Iterate Over a List

# %%
lst2 = ['dog', 'cat', 'ant']
for val in lst2:
    print('The lucky animal is: ', val)

print("*"*20)

# %% [markdown]
# ### 4.3.3 Looping Over Dictionaries

# %%
dit0 = {'cow': 800, 'dog': 50, 'cat': 15, 'ant': 0.001}
keys = dit0.keys()
for key in keys:
    print('The kay is:', key, '\tAnd the value of that key is:', dit0[key])

# %% [markdown]
# ### 4.3.4 Looping Over the Values in a Dictionary

# %%
for val in dit0.values():
    print('value is:', val)

# %% [markdown]
# ### 4.3.5 Iterating Over Key:Value Pairs in a Dictionary

# %%
for k,v in dit0.items():
    print(f'The key is: {k} \tAnd its value is: {v}')

# %% [markdown]
# ## Ch5. Functions and Comments

# %% [markdown]
# ### 5.3.1 Comments Recap

# %%
# creating lists
lst0 = [1 ,21 ,12 , 'dog'] # my first list
# lst1 = [ ’ this ’, ’ that ’, ’ then ’]
# printing the lists
print(lst0)
print(lst1)
"""
This code gives an error because lst1 is being called and printed 
while the line defining it is commented so not even compiled
"""

# %% [markdown]
# ### 5.3.2 Functions

# %%
#Q1
def my_pi_function():
    return 3.14159265359

#Q2
def my_pi_round_function(dic_plc):
    pi = round(my_pi_function(),dic_plc)
    return pi

#Q3
def circle(r):
    """
    This function takes the radius as input.
    Outputs:
        Diameter
        Circumference
        Area
    """
    diameter = 2*r
    circumference = 2 * my_pi_function() * r
    area = my_pi_function() * (r**2)
    return diameter, circumference, area

print(my_pi_function())
print(my_pi_round_function(3))
print(circle(3))
# Out:
# 3.14159265359
# 3.142
# (6, 18.849555921540002, 28.27433388231)

# %% [markdown]
# ## Ch6. Modules

# %% [markdown]
# ### 6.3.1 Importing Libraries

# %%
#Q1
import numpy

print(numpy.pi)
# Out:
# 3.141592653589793

# %%
#Q2
import numpy as np

print(np.pi)
# Out:
# 3.141592653589793

# %%
#Q3
from numpy import pi

print(pi)
# Out:
# 3.141592653589793

# %%
#Q4
from numpy import pow, sqrt

print(pow(4,2))
print(sqrt(4))
# Out:
# 16
# 2.0

# %% [markdown]
# ### 6.3.2 Creating Modules

# %%
import mymodule

height = 2.3 
width = 4.25
round_factor = 2

print(mymodule.rect(height, width, round_factor))

length = 3.5

c, a = mymodule.is_square(height,width)
c, a = mymodule.is_square(length,length)
# Out:
# (13.1, 9.77)
# This is a Rectangle
# This is a Square

# %% [markdown]
# ## Ch7. More on Functions and Variables

# %% [markdown]
# ### 7.5.1 Mutable versus Immutable

# %%
#Q1
my_list = ['dog', 'cat', 'ant']
print(id(my_list), my_list)
my_list[2] = 'cow'
print(id(my_list), my_list)

#Q2
def change_item(lst, idx, new_val):
    if type(lst) is list or type(lst) is tuple:
        if idx >= len(lst):
            print('Can not change the value, Index is out of bounds')
        else:
            lst[idx] = new_val
    elif type(lst) is dict:
        k = list(lst.keys())
        if idx >= len(k):
            print('Can not change the value, Index is out of bounds')
        else:
            lst[k[idx]] = new_val

new_lst = [1,2,15,4]
print(id(new_lst), new_lst)
change_item(new_lst, 2, 3)
print(id(new_lst), new_lst)

#Q3 
my_dict = {'first': 1, 'second': 2, 'third': 5}
print(id(my_dict), my_dict)
change_item(my_dict, 2, 3)
print(id(my_dict), my_dict)

#Q4 
# str0 = 'Hello World!!'
# print(id(str0), str0)
# str0[3] = 'k'
# print(id(str0), str0)
# This code will raise an error because str is immutable so we can't change its content after its created

#Q5 
# my_tuple = (1,2,3,4)
# change_item(my_tuple, 2, 3)
# This will also raise an error because tuples are immutable.
# Out:
# 126380975422336 ['dog', 'cat', 'ant']
# 126380975422336 ['dog', 'cat', 'cow']
# 126380975422144 [1, 2, 15, 4]
# 126380975422144 [1, 2, 3, 4]
# 126380975421696 {'first': 1, 'second': 2, 'third': 5}
# 126380975421696 {'first': 1, 'second': 2, 'third': 3}

# %% [markdown]
# ### 7.5.2 More on Functions

# %%
def rect(*args, **kwargs):
    if 'round_factor' in kwargs:
        r_factor = kwargs['round_factor']
    else:
        r_factor = 2

    if len(args) == 1:
        print('This is a Square')
        circumference = round(4*args[0], r_factor)
        area = round(args[0] ** 2, r_factor) 
    elif len(args) == 2:
        print('This is a Rectangle')
        circumference = round(2 * (args[0]+args[1]), r_factor)
        area = round(args[0] * args[1], r_factor)

    return circumference, area

print(rect(3.25, round_factor= 3))
print(rect(3.52, 5.22))
# Out:
# This is a Square
# (13.0, 10.562)
# This is a Rectangle
# (17.48, 18.37)

# %% [markdown]
# ### 7.5.3 Decorators

# %%
import time

def my_func(func):
    def internal(N):
        start_time = time.time()
        func(N)
        end_time = time.time()
        dur = end_time - start_time
        print(f'The function took {dur} seconds')
    
    return internal

@my_func
def foo(N):
    y = 0
    for i in range(N):
        y += 1

foo(1000)
# Out:
# The function took 3.3855438232421875e-05 seconds

# %% [markdown]
# ## Ch8. Basics of Classes

# %% [markdown]
# ### 8.4.1 Classes

# %%
#Q1 
class shape:
    def __init__(self, s: str):
        self.shape = s
    
    def print_description(self):
        print(f"This shape is a {self.shape}")

obj0 = shape('square')
obj0.print_description()

#Q2,Q3
class circle(shape):
    def __init__(self, s, r):
        super().__init__(s)
        self.radius = r
    
    def diameter(self):
        self.d = self.radius * 2
    
    def circumference(self):
        self.c = self.radius* 2 * 3.14
    
    def area(self):
        self.a = 3.14 * (self.radius ** 2)

    def calculate(self):
        self.diameter()
        self.circumference()
        self.area()
        return self.d, self.c, self.a
    
    def print_description(self):
        print(f"This shape is a {self.shape}")
        print(f"Circle Radius is: {self.radius} \n- Diameter: {self.d} \n- Circumference: {self.c} \n- Area: {self.a}")

obj1 = circle('circle', 1)
# Note that if we tried printing the description before calcutaling it will give us an errer
# because we didn't inialize the values so they don't exist unless we call calculate() 
# obj1.print_description()
d, c, a = obj1.calculate()
obj1.print_description()

    
#Q4
class rect(shape):
    def __init__(self, s, h, w):
        super().__init__(s)
        self.height = h
        self.width = w
        self.c = 0
        self.a = 0
    
    def circumference(self):
        self.c = 2 * (self.height + self.width)
    
    def area(self):
        self.a = self.height * self.width

    def calculate(self):
        self.circumference()
        self.area()
        return self.c, self.a
    
    def print_description(self):
        print(f"This shape is a {self.shape}")
        print(f"Rect Height is: {self.height} \n- Width: {self.width} \n- Circumference: {self.c} \n- Area: {self.a}")

obj2 = rect('Rectangle', 3, 2)
obj2.print_description()
c, a = obj2.calculate()
obj2.print_description()
# Here since we initialized the circumference and area we don't get an error if we
# ran print_description() before calculate()
# Out:
# This shape is a square
# This shape is a circle
# Circle Radius is: 1
# - Diameter: 2
# - Circumference: 6.28
# - Area: 3.14
# This shape is a Rectangle
# Rect Height is: 3
# - Width: 2
# - Circumference: 0
# - Area: 0
# This shape is a Rectangle
# Rect Height is: 3
# - Width: 2
# - Circumference: 10
# - Area: 6

# %% [markdown]
# ## CH9. Input and Output

# %% [markdown]
# ### 9.5.1 Deeper into the Print Function

# %%
print("Hello from Mars", "This is Mark", sep='\t', end=' (This the end of the line)!!!\n')
# Out:
# Hello from mars	This is Mark (This the end of the line)!!!

# %% [markdown]
# ### 9.5.2 Data input and output

# %%
fid = open('file.txt', 'w')
fid.write('Hello Mark from Mars')
fid.close()

fid = open('file.txt', 'w')
print('This Lenus from Venus', file=fid)
fid.close()

# Here we will notice that the second write command override the first one
# so we need to use append instead of write

# %%
fid = open('file.txt', 'a')
fid.write('And this here is Hepburn. \tCan you guess where I am from')
fid.close()

# %%
fid = open('file.txt', 'r')
lines = fid.readlines()
fid.close()
for line in lines:
    print(line)
    print(type(line))
# Out:
# This Lenus from Venus
#
# <class 'str'>
# And this here is Hepburn. 	Can you guess where I am from
# <class 'str'>

# %% [markdown]
# ### 9.5.3 Data input and output using 'with'

# %%
with open('file.txt', 'w') as fid:
    print('Hoo Hoo Hoo, I killed them all', file=fid)

with open('file.txt', 'r') as fid:
    print(fid.readline())
# Out:
# Hoo Hoo Hoo, I killed them all

# %% [markdown]
# ### 9.5.4 Pickle library

# %%
import pickle

my_dict = {'first': 1, 'second': 2, 'third': 3}
my_list = [4,5,6]
my_tuple = (7,8,9)

with open('file2.pkl', 'wb') as f:
    pickle.dump(my_dict,f)
    pickle.dump(my_list,f)
    pickle.dump(my_tuple,f)

with open('file2.pkl', 'rb') as f:
    my_dict = pickle.load(f)
    my_list = pickle.load(f)
    my_tuple = pickle.load(f)

print(my_dict)
print(my_list)
print(my_tuple)

with open('file3.pkl', 'wb') as fl:
    pickle.dump({'my_dict': my_dict, 'my_list': my_list, 'my_tuple': my_tuple}, fl)

with open('file3.pkl', 'rb') as fl:
    data = pickle.load(fl)

print(data)
# Out:
# {'first': 1, 'second': 2, 'third': 3}
# [4, 5, 6]
# (7, 8, 9)
# {'my_dict': {'first': 1, 'second': 2, 'third': 3}, 'my_list': [4, 5, 6], 'my_tuple': (7, 8, 9)}

# %% [markdown]
# ## Ch10. Numerical Python

# %% [markdown]
# ### 10.5.1 Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

#Q1
x_vals = np.linspace(0, 6*np.pi, 1000)
sin_vals = np.sin(x_vals)
sin_squared_vals = np.sin(x_vals**2)
cos_vals = np.cos(x_vals)
plt.figure(figsize=(15,5))
plt.plot(x_vals,sin_vals,label='Sin Curve', color='r')
plt.plot(x_vals,sin_squared_vals,label='Sin Squared Curve', color='g')
plt.plot(x_vals,cos_vals,label='Cos Curve', color='navy')
plt.title('Sinsoudal Curves')
plt.xlabel('X')
plt.ylabel('Sinsoudal Val')
plt.legend()
plt.show()

#Q2
plt.figure(figsize=(5,5))
plt.subplot(3,1,1)
plt.plot(x_vals,sin_vals)
plt.title('Sin Function')
plt.xlabel('x')
plt.ylabel('sin(x)')

plt.figure(figsize=(5,5))
plt.subplot(3,1,2)
plt.plot(x_vals,sin_squared_vals)
plt.title('Sin Function of x squared')
plt.xlabel('x')
plt.ylabel('sin(x^2)')

plt.figure(figsize=(5,5))
plt.subplot(3,1,3)
plt.plot(x_vals,cos_vals)
plt.title('Cos Function')
plt.xlabel('x')
plt.ylabel('cos(x)')

plt.show()

# %% [markdown]
# ### 10.5.2 Matices and Vectors

# %%
import numpy as np

#Q1
vector = np.array([1,2,3])
print(vector.shape)
print(vector+3)
print(vector-2)
print(vector*5)
print(vector/2)
print('-'*50)

#Q2
mat1 = np.array([[1,2,3]])
print(mat1.shape)
print(mat1+3)
print(mat1-2)
print(mat1*5)
print(mat1/2)
print('-'*50)
# Out:
# (3,)
# [4 5 6]
# [-1  0  1]
# [ 5 10 15]
# [0.5 1.  1.5]
# --------------------------------------------------
# (1, 3)
# [[4 5 6]]
# [[-1  0  1]]
# [[ 5 10 15]]
# [[0.5 1.  1.5]]
# --------------------------------------------------

# %%
#Q3,Q4
mat2 = np.random.randint(low=0,high=10,size=[5,4])
print(mat2)
print(np.max(mat2))
vec0 = np.array([1,2,3,4])
print(mat2+vec0)
print(mat2-vec0)
print(mat2*vec0)
print(mat2/vec0)
# Out:
# [[0 6 9 4]
#  [8 7 1 3]
#  [6 3 3 4]
#  [3 4 8 9]
#  [7 5 0 4]]
# 9
# [[ 1  8 12  8]
#  [ 9  9  4  7]
#  [ 7  5  6  8]
#  [ 4  6 11 13]
#  [ 8  7  3  8]]
# [[-1  4  6  0]
#  [ 7  5 -2 -1]
#  [ 5  1  0  0]
#  [ 2  2  5  5]
#  [ 6  3 -3  0]]
# [[ 0 12 27 16]
#  [ 8 14  3 12]
#  [ 6  6  9 16]
#  [ 3  8 24 36]
#  [ 7 10  0 16]]
# [[0.         3.         3.         1.        ]
#  [8.         3.5        0.33333333 0.75      ]
#  [6.         1.5        1.         1.        ]
#  [3.         2.         2.66666667 2.25      ]
#  [7.         2.5        0.         1.        ]]

# %%
#Q5
print(mat2)
mat3 = np.array([[1],[2],[3],[4],[5]])
print(mat2+mat3)
print(mat2-mat3)
print(mat2*mat3)
print(mat2/mat3)
# Out:
# [[6 5 5 0]
#  [0 4 5 5]
#  [4 4 2 4]
#  [8 3 1 6]
#  [3 7 1 7]]
# [[ 7  6  6  1]
#  [ 2  6  7  7]
#  [ 7  7  5  7]
#  [12  7  5 10]
#  [ 8 12  6 12]]
# [[ 5  4  4 -1]
#  [-2  2  3  3]
#  [ 1  1 -1  1]
#  [ 4 -1 -3  2]
#  [-2  2 -4  2]]
# [[ 6  5  5  0]
#  [ 0  8 10 10]
#  [12 12  6 12]
#  [32 12  4 24]
#  [15 35  5 35]]
# [[6.         5.         5.         0.        ]
#  [0.         2.         2.5        2.5       ]
#  [1.33333333 1.33333333 0.66666667 1.33333333]
#  [2.         0.75       0.25       1.5       ]
#  [0.6        1.4        0.2        1.4       ]]

# %%
#Q6
mat4 = np.random.randint(low=0, high=10,size=[5,4])
print(mat2,mat4,sep='\n')
print('-'*50)
print(mat2+mat4)
print(mat2-mat4)
print(mat2*mat4)
print(mat2/mat4)
# Out:
# [[6 5 5 0]
#  [0 4 5 5]
#  [4 4 2 4]
#  [8 3 1 6]
#  [3 7 1 7]]
# [[7 6 7 9]
#  [6 7 4 9]
#  [5 2 4 0]
#  [1 3 2 7]
#  [3 1 9 5]]
# --------------------------------------------------
# [[13 11 12  9]
#  [ 6 11  9 14]
#  [ 9  6  6  4]
#  [ 9  6  3 13]
#  [ 6  8 10 12]]
# [[-1 -1 -2 -9]
#  [-6 -3  1 -4]
#  [-1  2 -2  4]
#  [ 7  0 -1 -1]
#  [ 0  6 -8  2]]
# [[42 30 35  0]
#  [ 0 28 20 45]
#  [20  8  8  0]
#  [ 8  9  2 42]
#  [ 9  7  9 35]]
# [[0.85714286 0.83333333 0.71428571 0.        ]
#  [0.         0.57142857 1.25       0.55555556]
#  [0.8        2.         0.5               inf]
#  [8.         1.         0.5        0.85714286]
#  [1.         7.         0.11111111 1.4       ]]
# /tmp/ipykernel_8467/1876463513.py:8: RuntimeWarning: divide by zero encountered in divide
#   print(mat2/mat4)

# %%
#Q6
mat5 = np.random.randint(low=0,high=10,size=[4,5])
print(mat4,mat5,sep='\n')
print('-'*50)
print(mat4@mat5)
# Out:
# [[7 6 7 9]
#  [6 7 4 9]
#  [5 2 4 0]
#  [1 3 2 7]
#  [3 1 9 5]]
# [[1 8 6 9 3]
#  [3 4 6 4 8]
#  [2 4 0 1 9]
#  [0 3 3 9 0]]
# --------------------------------------------------
# [[ 39 135 105 175 132]
#  [ 35 119 105 167 110]
#  [ 19  64  42  57  67]
#  [ 14  49  45  86  45]
#  [ 24  79  39  85  98]]

# %%
#Q7
print(mat2)
print(np.min(mat2))
print(np.max(mat2))
print(np.mean(mat2))
print(np.std(mat2))
print(np.argmax(mat2))
print(np.argmin(mat2))
# Out:
# [[6 5 5 0]
#  [0 4 5 5]
#  [4 4 2 4]
#  [8 3 1 6]
#  [3 7 1 7]]
# 0
# 8
# 4.0
# 2.258317958127243
# 12
# 3

# %%
#Q8,Q9
mat6 = np.random.randint(0,10, size=[5,4])
idx = np.argmax(mat6)
row = idx // mat6.shape[1]
col = idx % mat6.shape[1]
print(mat6,idx,row,col,sep='\n')
print('-'*50)
print(np.mean(mat6,axis=0))
print(np.mean(mat6,axis=1))
print(np.max(mat6,axis=0))
print(np.min(mat6,axis=1))
print(np.argmin(mat6,axis=1))
# Out:
# [[5 5 5 6]
#  [3 7 6 7]
#  [9 7 3 0]
#  [2 3 3 7]
#  [3 3 7 9]]
# 8
# 2
# 0
# --------------------------------------------------
# [4.4 5.  4.8 5.8]
# [5.25 5.75 4.75 3.75 5.5 ]
# [9 7 7 9]
# [5 3 0 2 3]
# [0 0 3 0 0]

# %% [markdown]
# ## Ch11. Deeper into Classes

# %% [markdown]
# ### 11.5.1 Deeper into Strings Creation

# %%
s1 = "I'm " + str(22) + " years old, and my gpa is: " + str(2.544)
print(s1)
s2 = "I'm %d years old, and my gpa is: %f"%(22,2.544)
s3 = "I'm %03d years old, and my gpa is: %0.01f"%(22,2.544)
print(s2,s3,sep='\n')
s4 = "I'm {} years old, and my gpa is: {}".format(22,2.544)
s5 = "I'm {:04d} years old, and my gpa is: {:0.02f}".format(22,2.544)
print(s4,s5,sep='\n')
age = 22
gpa = 2.544
s6 = f"I'm {age} years old, and my gpa is: {gpa}"
s7 = f"I'm {age:05d} years old, and my gpa is: {gpa:0.01f}"
print(s6,s7,sep='\n')
# Out:
# I'm 22 years old, and my gpa is: 2.544
# I'm 22 years old, and my gpa is: 2.544000
# I'm 022 years old, and my gpa is: 2.5
# I'm 22 years old, and my gpa is: 2.544
# I'm 0022 years old, and my gpa is: 2.54
# I'm 22 years old, and my gpa is: 2.544
# I'm 00022 years old, and my gpa is: 2.5

# %% [markdown]
# ### 11.5.2 Class Strings

# %%
class rectangle():
    def __init__(self,*args):
        if len(args) == 1:
            self.shape = 'Square'
            self.height = args[0]
            self.width = args[0]
        else:
            self.shape = 'Rectangle'            
            self.height = args[0]
            self.width = args[1]

    def calculate_circumference(self):
        self.circ = 2*(self.height+self.width)
        return self.circ

    def calculate_area(self):
        self.area = self.height*self.width
        return self.area
    
    def __str__(self):
        self.calculate_circumference()
        self.calculate_area()
        return f"This is a {self.shape}\n - Height = {self.height}\n - Width = {self.width}\n - Circumference = {self.circ}\n - Area = {self.area}"
    
    def str(self):
        self.calculate_circumference()
        self.calculate_area()
        return f"This is a {self.shape}\n - Height = {self.height}\n - Width = {self.width}\n - Circumference = {self.circ}\n - Area = {self.area}"
    
sqr = rectangle(5)
rect = rectangle(4,8)
s1 = str(sqr)
s2 = str(rect)
print(s1,sqr,sep='\n')
print(s2,rect,sep='\n')

# the str(self) wasn't used in any of the calls since str(sqr) and str(rect) internally calls __str__(self) method
# Also print internally calls __str__(self) method so we never use str(self)
# To use it we have to run it like this:
# print(sqr.str()) but that's extra steps since it's the same as __str__(self) so the str(self) method is redundent
# Out:
# This is a Square
#  - Height = 5
#  - Width = 5
#  - Circumference = 20
#  - Area = 25
# This is a Square
#  - Height = 5
#  - Width = 5
#  - Circumference = 20
#  - Area = 25
# This is a Rectangle
#  - Height = 4
#  - Width = 8
#  - Circumference = 24
#  - Area = 32
# This is a Rectangle
#  - Height = 4
#  - Width = 8
#  - Circumference = 24
#  - Area = 32

# %% [markdown]
# ### 11.5.3 Class With

# %%
import time

class timer:
    def __init__(self,name):
        self.name = name

    def iterate(self,n):
        self.n_iter = n
        y = 0
        for i in range(self.n_iter):
            y += 1

    def __enter__(self):
        self.start_time = time.time()
        return self

    def __exit__(self,type,value,traceback):
        self.dur = time.time() - self.start_time
        print(f"The iterator {self.name} took {self.dur} seconds to iterate {self.n_iter} iterations")
    
with timer('Thousander') as itr:
    itr.iterate(1000)

with timer('TenThousander') as itr:
    itr.iterate(10000)

with timer('HunderedThousander') as itr:
    itr.iterate(100000)
# Out:
# The iterator Thousander took 2.9087066650390625e-05 seconds to iterate 1000 iterations
# The iterator TenThousander took 0.0002701282501220703 seconds to iterate 10000 iterations
# The iterator HunderedThousander took 0.003751993179321289 seconds to iterate 100000 iterations

# %% [markdown]
# ### 11.5.4 Class Get/Set - 11.5.5 Calling a class

# %%
class rectangle():
    def __init__(self,*args):
        if len(args) == 1:
            self.shape = 'Square'
            self.my_height = args[0]
            self.my_width = args[0]
        else:
            self.shape = 'Rectangle'            
            self.my_height = args[0]
            self.my_width = args[1]

    def calculate_circumference(self):
        self.circ = 2*(self.height+self.width)
        return self.circ

    def calculate_area(self):
        self.area = self.height*self.width
        return self.area
    
    def __str__(self):
        return f"This is a {self.shape}\n - Height = {self.height}\n - Width = {self.width}\n - Circumference = {self.circ}\n - Area = {self.area}"
    
    def __call__(self, *args, **kwds):
        return self.calculate_circumference(), self.calculate_area()
    
    @property
    def height(self):
        return self.my_height
    
    @height.setter
    def height(self, new_height):
        self.my_height = new_height
        # To make good use of setters here we should call the calculate functions again so they update after changing 
        # the height or the width 
        # self.calculate_circumference()
        # self.calculate_area()

    @property
    def width(self):
        return self.my_width
    
    @width.setter
    def width(self, new_width):
        self.my_width = new_width


rect = rectangle(7,8)
rect.calculate_circumference()
rect.calculate_area()
print(rect)
rect.width = 5
print(rect)
circ, area = rect()
print(circ,area)
# Out:
# This is a Rectangle
#  - Height = 7
#  - Width = 8
#  - Circumference = 30
#  - Area = 56
# This is a Rectangle
#  - Height = 7
#  - Width = 5
#  - Circumference = 30
#  - Area = 56
# 24 35

# %% [markdown]
# ## Ch12. Images and Basic Operations

# %% [markdown]
# ### 12.4.1 Loading Images

# %%
import skimage.io
import numpy as np

rgb_img = skimage.io.imread('practical_imgs/sb20_rgb.png')
print(type(rgb_img))
print(rgb_img.dtype)
print(np.min(rgb_img), np.max(rgb_img))
rgb_img = rgb_img/255
print(np.min(rgb_img), np.max(rgb_img))
print(f'values for pixel (20,20):\n - Red: {rgb_img[20,20,0]}\n - Green: {rgb_img[20,20,1]}\n - Blue: {rgb_img[20,20,2]}')
print(rgb_img.shape)
# Out:
# <class 'numpy.ndarray'>
# uint8
# 1 255
# 0.00392156862745098 1.0
# values for pixel (20,20):
#  - Red: 0.1803921568627451
#  - Green: 0.17254901960784313
#  - Blue: 0.21568627450980393
# (480, 640, 3)

# %% [markdown]
# ### 12.4.2 Excess Green Filtering

# %%
R = rgb_img[:,:,0]
G = rgb_img[:,:,1]
B = rgb_img[:,:,2]
exG = 2*G - R - B
print(exG.shape)
print(np.min(exG),np.max(exG))
print("Notice that we have negative sign here that's because when we converted the range of the image\n" \
"it also changed the dtype from uint8 to float64")
green_mask = np.zeros_like(rgb_img[:,:,0],dtype=np.uint8)
threshold = .05
green_mask[exG>=threshold] = 255
skimage.io.imsave('Output_imgs/green_mask.png',green_mask)
# Out:
# (480, 640)
# -0.17254901960784313 0.3803921568627452
# Notice that we have negative sign here that's because when we converted the range of the image
# it also changed the dtype from uint8 to float64

# %% [markdown]
# ### 12.4.3 Msked Manipulation and IoU

# %%
#Q1
smap = skimage.io.imread('practical_imgs/sb20_smap.png')
rgb2 = rgb_img.copy()
unique_vals = np.unique(smap)

#Q2
for i in range(1,len(unique_vals)):
    rand_color = np.random.randint(100,255,[3,])/255
    rgb2[smap==unique_vals[i]] = rand_color

alpha = 0.6
outrgb = alpha * rgb_img + (1-alpha) * rgb2
outrgb = (outrgb*255).astype(np.uint8)
skimage.io.imsave("Output_imgs/merged_rgb.png",outrgb)

#Q3 
IoU = np.sum(np.logical_and(green_mask,smap)) / np.sum(np.logical_or(green_mask,smap))
print("IoU is:",IoU)
# Out:
# IoU is: 0.7071369975389664

# %% [markdown]
# ### 12.4.4 Colour Space Conversion and Filtering

# %%
#Q1
from skimage.color import rgb2lab

Lab_img = rgb2lab(rgb_img)
print(f"Range for L Channel is: {np.min(Lab_img[:,:,0])} - {np.max(Lab_img[:,:,0])}")
print(f"Range for a Channel is: {np.min(Lab_img[:,:,1])} - {np.max(Lab_img[:,:,1])}")
print(f"Range for b Channel is: {np.min(Lab_img[:,:,2])} - {np.max(Lab_img[:,:,2])}")

#Q2
Lab_mask = np.zeros((Lab_img.shape[0],Lab_img.shape[1]),dtype=np.uint8)
threshold2 = -4
Lab_mask[Lab_img[:,:,1] <= threshold2] = 255
skimage.io.imsave('Output_imgs/Lab_mask.png',Lab_mask)

#Q3
Lab_IoU = np.sum(np.logical_and(Lab_mask,smap)) / np.sum(np.logical_or(Lab_mask,smap))
print("Lab mask IoU is:",Lab_IoU)
# Out:
# Range for L Channel is: 2.005919609976587 - 98.80753743146377
# Range for a Channel is: -23.974214893488167 - 18.087982435485525
# Range for b Channel is: -22.27535141408028 - 38.39685037304894
# Lab mask IoU is: 0.6472612006648885

# %% [markdown]
# ### 12.4.5 Edge Detection

# %%
#Q1
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
from skimage.filters import sobel

plaid = skimage.io.imread('practical_imgs/plaid.jpeg')
plaid = rgb2gray(plaid)
f_v = np.array([[-1,0,1],
                [-2,0,2],
                [-1,0,1]])
f_h = np.array([[-1,-2,-1],
                [0,0,0],
                [1,2,1]])

v_map = np.zeros_like(plaid)
h_map = np.zeros_like(plaid)
for i in range(1,plaid.shape[0]-2):
    for j in range(1,plaid.shape[1]-2):
        sub_region = plaid[i-1:i+2,j-1:j+2]
        v_map[i,j] = (f_v*sub_region).sum()
        h_map[i,j] = (f_h*sub_region).sum()
mag = np.sqrt(v_map**2+h_map**2)

#Q2
fig, axes = plt.subplots(1,3,figsize=(10,5))
ax = np.ravel(axes)

ax[0].imshow(h_map)
ax[0].set_title('Horizontal map')
ax[1].imshow(v_map)
ax[1].set_title('Vertical map')
ax[2].imshow(mag)
ax[2].set_title('Edges')

plt.tight_layout()
plt.show()

#Q3
sobel_filter = sobel(plaid)

fig, axes = plt.subplots(1,2,figsize=(8,4))
ax = np.ravel(axes)

ax[0].imshow(mag)
ax[0].set_title('Manual Implementation')
ax[1].imshow(sobel_filter)
ax[1].set_title('Built in Implementation')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ch13. Data Structures
